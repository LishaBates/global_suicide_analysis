# %%
import pandas as pd 
import numpy as np

# %%
gdp= pd.read_csv("../Data/Cleaned_data/GDP.csv")
gdp
# Out:
#       Unnamed: 0            Region/Country/Area  Year  \
# 0              1  Total, all countries or areas  2005
# 1              2  Total, all countries or areas  2010
# 2              3  Total, all countries or areas  2015
# 3              4  Total, all countries or areas  2018
# 4              5  Total, all countries or areas  2019
# ...          ...                            ...   ...
# 5817        6781                       Zimbabwe  2010
# 5818        6782                       Zimbabwe  2015
# 5819        6783                       Zimbabwe  2018
# 5820        6784                       Zimbabwe  2019
# 5821        6785                       Zimbabwe  2020
#
#                                               Series       Value
# 0     GDP in current prices (millions of US dollars)  47,730,924
# 1     GDP in current prices (millions of US dollars)  66,461,443
# 2     GDP in current prices (millions of US dollars)  75,133,208
# ...

# %%
gdp = gdp.rename(columns={'Region/Country/Area':'Country'})
gdp
# Out:
#       Unnamed: 0                        Country  Year  \
# 0              1  Total, all countries or areas  2005
# 1              2  Total, all countries or areas  2010
# 2              3  Total, all countries or areas  2015
# 3              4  Total, all countries or areas  2018
# 4              5  Total, all countries or areas  2019
# ...          ...                            ...   ...
# 5817        6781                       Zimbabwe  2010
# 5818        6782                       Zimbabwe  2015
# 5819        6783                       Zimbabwe  2018
# 5820        6784                       Zimbabwe  2019
# 5821        6785                       Zimbabwe  2020
#
#                                               Series       Value
# 0     GDP in current prices (millions of US dollars)  47,730,924
# 1     GDP in current prices (millions of US dollars)  66,461,443
# 2     GDP in current prices (millions of US dollars)  75,133,208
# ...

# %%
pop= pd.read_csv("../Data/Cleaned_data/Suicides_per_100K.csv")
pop
# Out:
#       Unnamed: 0      Country  Year  Per_100K
# 0           3659     Zimbabwe  2019      23.6
# 1           3476     Zimbabwe  2018      23.9
# 2           3293     Zimbabwe  2017      25.9
# 3           3110     Zimbabwe  2016      28.7
# 4           2927     Zimbabwe  2015      30.7
# ...          ...          ...   ...       ...
# 3655         732  Afghanistan  2004       7.8
# 3656         549  Afghanistan  2003       7.7
# 3657         366  Afghanistan  2002       7.9
# 3658         183  Afghanistan  2001       7.9
# 3659           0  Afghanistan  2000       7.7
#
# [3660 rows x 4 columns]

# %% [markdown]
# merge both dataframes and connect on Country and Year. Outer Join  Left is GDP Right is POP

# %%
gdp_pop_df=pd.merge(gdp,pop,on=['Country','Year'], how='outer',indicator=True)

gdp_pop_df
# Out:
#       Unnamed: 0_x                        Country  Year  \
# 0              1.0  Total, all countries or areas  2005
# 1              8.0  Total, all countries or areas  2005
# 2             15.0  Total, all countries or areas  2005
# 3             22.0  Total, all countries or areas  2005
# 4              2.0  Total, all countries or areas  2010
# ...            ...                            ...   ...
# 8664           NaN                    Afghanistan  2004
# 8665           NaN                    Afghanistan  2003
# 8666           NaN                    Afghanistan  2002
# 8667           NaN                    Afghanistan  2001
# 8668           NaN                    Afghanistan  2000
#
#                                                  Series       Value  \
# 0        GDP in current prices (millions of US dollars)  47,730,924
# 1                           GDP per capita (US dollars)       7,298
# 2     GDP in constant 2010 prices (millions of US do...  56,429,253
# ...

# %%
#convert to CSV
#gdp_pop_df.to_csv('Suicides_By_country_by_GDP.csv')

# %%
#now add population, groth and mortality indicators df to this df (total of 3 df's combined)

# %%
all_the_goodies=pd.merge(gdp,pop,on=['Country','Year'], how='outer',indicator=True)

all_the_goodies
# Out:
#       Unnamed: 0_x                        Country  Year  \
# 0              1.0  Total, all countries or areas  2005
# 1              8.0  Total, all countries or areas  2005
# 2             15.0  Total, all countries or areas  2005
# 3             22.0  Total, all countries or areas  2005
# 4              2.0  Total, all countries or areas  2010
# ...            ...                            ...   ...
# 8664           NaN                    Afghanistan  2004
# 8665           NaN                    Afghanistan  2003
# 8666           NaN                    Afghanistan  2002
# 8667           NaN                    Afghanistan  2001
# 8668           NaN                    Afghanistan  2000
#
#                                                  Series       Value  \
# 0        GDP in current prices (millions of US dollars)  47,730,924
# 1                           GDP per capita (US dollars)       7,298
# 2     GDP in constant 2010 prices (millions of US do...  56,429,253
# ...

# %%
#move all 3 df's to one csv

# %%
#all_the_goodies.to_csv('Suicides_country_GDP_Population.csv')

# %%
#bring in wiki by sex table for 2000-2019. due to error recieved when pulling in the file I had to use latin-1... not sure why but it worked 
sex=pd.read_csv("../Data/Cleaned_data/Suicides_by_sex.csv")
sex
# Out:
#       Row Labels  Sum of Male  Sum of Female  Sum of All
# 0    Afghanistan        148.8          136.8       144.0
# 1         Africa        432.0          124.8       268.8
# 2        Albania        127.2           52.8        88.8
# 3        Algeria         79.2           45.6        62.4
# 4       Americas        340.8           98.4       216.0
# ..           ...          ...            ...         ...
# 266       Zambia        616.8          127.2       345.6
# 267     Zanzibar          NaN            NaN         NaN
# 268     Zimbabwe        907.2          324.0       566.4
# 269      (blank)          NaN            NaN         NaN
# 270  Grand Total      65470.9        18386.7     40919.3
#
# [271 rows x 4 columns]

# %%
#gdp_sex=pd.merge(gdp,sex,on='Country', how='outer',indicator=True)
#gdp_sex
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17012\3518492214.py in <module>
# ----> 1 gdp_sex=pd.merge(gdp,sex,on='Country', how='outer',indicator=True)
#       2 gdp_sex
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     698             self.right_join_keys,
#     699             self.join_names,
# --> 700         ) = self._get_merge_keys()
#     701
# ...

# %%
#convert to CSV
#gdp_sex.to_csv('Suicides_sex_by_GDP.csv')
