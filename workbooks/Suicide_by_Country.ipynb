# %%
import pandas as pd 
import numpy as np

# %%
who= pd.read_csv("../Data/WHOMortalityDatabase_Deaths_sex_age_a_country_area_year-Self-inflicted injuries_7th December 2022 09_50.csv")
who
# Out:
#        Region_Code                      Region_Name Country_Code  \
# 0               EU                           Europe          ALB
# 1               EU                           Europe          ALB
# 2               EU                           Europe          ALB
# 3               EU                           Europe          ALB
# 4               EU                           Europe          ALB
# ...            ...                              ...          ...
# 290740         NAC  North America and the Caribbean          USA
# 290741         NAC  North America and the Caribbean          USA
# 290742         NAC  North America and the Caribbean          USA
# 290743         NAC  North America and the Caribbean          USA
# 290744         NAC  North America and the Caribbean          USA
#
#                     Country_Name  Year     Sex    Age_group        Age  \
# 0                        Albania  1987     All      Age_all      [All]
# ...

# %%
who.Age=who.Age.str.replace('[', '').str.replace(']','')
# Out:
# C:\Users\lisha\AppData\Local\Temp\ipykernel_16084\2841137414.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   who.Age=who.Age.str.replace('[', '').str.replace(']','')

# %%
who.to_csv("../Data/Suicides_by_Country.csv", index=False)

# %%
who
# Out:
#        Region_Code                      Region_Name Country_Code  \
# 0               EU                           Europe          ALB
# 1               EU                           Europe          ALB
# 2               EU                           Europe          ALB
# 3               EU                           Europe          ALB
# 4               EU                           Europe          ALB
# ...            ...                              ...          ...
# 290740         NAC  North America and the Caribbean          USA
# 290741         NAC  North America and the Caribbean          USA
# 290742         NAC  North America and the Caribbean          USA
# 290743         NAC  North America and the Caribbean          USA
# 290744         NAC  North America and the Caribbean          USA
#
#                     Country_Name  Year     Sex    Age_group      Age  Number  \
# 0                        Albania  1987     All      Age_all      All    73.0
# ...
