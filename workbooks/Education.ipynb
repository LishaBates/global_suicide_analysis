# %%
import pandas as pd
import numpy as np

# %%
education_df= pd.read_csv("../Data/SYB65_309_202209_Education.csv")
education_df
# Out:
#       Index            Region/Country/Area  Year  \
# 0         1  Total, all countries or areas  2005
# 1         1  Total, all countries or areas  2005
# 2         1  Total, all countries or areas  2005
# 3         1  Total, all countries or areas  2005
# 4         1  Total, all countries or areas  2005
# ...     ...                            ...   ...
# 7277    716                       Zimbabwe  2015
# 7278    716                       Zimbabwe  2015
# 7279    716                       Zimbabwe  2020
# 7280    716                       Zimbabwe  2020
# 7281    716                       Zimbabwe  2020
#
#                                                  Series    Value Footnotes  \
# 0     Students enrolled in primary education (thousa...  679,014       NaN
# 1               Gross enrollment ratio - Primary (male)    104.5       NaN
# 2             Gross enrollment ratio - Primary (female)     99.7       NaN
# ...

# %%
#drop footnotes
education_df = education_df.drop(columns =['Footnotes'])

# %%
#drop Source
education_df = education_df.drop(columns =['Source'])

# %%
#drop Index
education_df = education_df.drop(columns =['Index'])

# %%
education_df
# Out:
#                 Region/Country/Area  Year  \
# 0     Total, all countries or areas  2005
# 1     Total, all countries or areas  2005
# 2     Total, all countries or areas  2005
# 3     Total, all countries or areas  2005
# 4     Total, all countries or areas  2005
# ...                             ...   ...
# 7277                       Zimbabwe  2015
# 7278                       Zimbabwe  2015
# 7279                       Zimbabwe  2020
# 7280                       Zimbabwe  2020
# 7281                       Zimbabwe  2020
#
#                                                  Series    Value
# 0     Students enrolled in primary education (thousa...  679,014
# 1               Gross enrollment ratio - Primary (male)    104.5
# 2             Gross enrollment ratio - Primary (female)     99.7
# 3     Students enrolled in secondary education (thou...  509,277
# 4             Gross enrollment ratio - Secondary (male)     65.8
# ...

# %%
#convert to CSV
education_df.to_csv('Education.csv')
